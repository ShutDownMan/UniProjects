# %%
import matplotlib.pyplot as plt
import numpy as np

rec_data = np.array([0.000001, 0.000001, 0.000002, 0.000002, 0.000003, 0.000006, 0.000011, 0.000022, 0.000044, 0.000087, 0.000162, 0.000299, 0.000583, 0.001147, 0.002140, 0.003606, 0.005557, 0.009469, 0.018406, 0.036950, 0.073453, 0.146819, 0.293320, 0.631125, 1.310695, 2.353630, 5.503026, 10.752140, 19.182081, 38.987392])
iter_data = np.array([0.000000, 0.000000, 0.000000, 0.000001, 0.000001, 0.000002, 0.000003, 0.000007, 0.000013, 0.000027, 0.000053, 0.000106, 0.000212, 0.000424, 0.000848, 0.001701, 0.003398, 0.006870, 0.013841, 0.027788, 0.055476, 0.109657, 0.217588, 0.436480, 0.872214, 1.744405, 3.497994, 6.980379, 13.985495, 27.925366])

print(rec_data.shape)

x_axis = [1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 65536, 131072, 262144, 524288, 1048576, 2097152, 4194304, 8388608, 16777216, 33554432, 67108864, 134217728, 268435456, 536870912]

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(x_axis, rec_data, color='tab:blue')
ax.plot(x_axis, iter_data, color='tab:orange')

# plt.yscale('log')
plt.xscale('log')

ax.set_title('line plot with data points')
plt.grid()

plt.show()
# Out:
# (30,)
